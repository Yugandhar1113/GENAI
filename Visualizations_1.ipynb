# %%
import pandas as pd
import numpy as np

# %%
df=pd.DataFrame(np.random.randint(0,100,10),columns=['space'])
df.head()
# Out:
#    space
# 0     55
# 1     63
# 2     81
# 3     96
# 4     52

# %%
df
# Out:
#    space
# 0     55
# 1     63
# 2     81
# 3     96
# 4     52
# 5     40
# 6     99
# 7     79
# 8     16
# 9     26

# %%
pip install matplotlib

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(10,5))

# %%
plt.plot(['sales'])
