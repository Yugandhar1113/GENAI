# %%
import numpy as np
from keras.models import Sequential
from keras.layers import Dense
from keras.optimizers import SGD

# %%
data=np.array([[0,0],[0,1],[1,0],[1,1]])

# %%
data
# Out:
# array([[0, 0],
#        [0, 1],
#        [1, 0],
#        [1, 1]])

# %%
X=data
y=np.array([[0], [0], [0], [1]])

# %%
X
# Out:
# array([[0, 0],
#        [0, 1],
#        [1, 0],
#        [1, 1]])

# %%
y
# Out:
# array([[0],
#        [0],
#        [0],
#        [1]])

# %%
model=Sequential()
model.add(Dense(1,input_dim=2,activation='sigmoid'))
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model.compile(optimizer=SGD(learning_rate=0.1), loss='binary_crossentropy', metrics=['accuracy'])
model.fit(X,y)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 522ms/step - accuracy: 0.7500 - loss: 0.7228

# %%
# Train the model
model.fit(X, y, epochs=100, verbose=1)

# Evaluate the model
loss, accuracy = model.evaluate(X, y)
print(f"\nAccuracy: {accuracy*100:.2f}%")

# Make predictions
print("\nPredictions:")
print(model.predict(X))
# Out:
# Epoch 1/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.7500 - loss: 0.7137
# Epoch 2/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.7500 - loss: 0.7051
# Epoch 3/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.7500 - loss: 0.6970
# Epoch 4/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.7500 - loss: 0.6893
# Epoch 5/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.7500 - loss: 0.6819
# Epoch 6/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.7500 - loss: 0.6750
# Epoch 7/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.7500 - loss: 0.6684
# Epoch 8/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.7500 - loss: 0.6622
# Epoch 9/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.7500 - loss: 0.6562
# Epoch 10/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.7500 - loss: 0.6506
# Epoch 11/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.7500 - loss: 0.6452
# Epoch 12/100
# ...

# %%
import numpy as np
from keras.models import Sequential
from keras.layers import Dense
from keras.optimizers import SGD

# Sample input data
X = np.array([[0, 0],
              [0, 1],
              [1, 0],
              [1, 1]])

# Output labels (AND gate)
y = np.array([[0], [0], [0], [1]])

# Build the model
model = Sequential()
model.add(Dense(5, input_dim=2, activation='relu'))  # Hidden layer with 5 nodes
model.add(Dense(1, activation='sigmoid'))            # Output layer for binary classification

# Compile the model
model.compile(optimizer=SGD(learning_rate=0.1), loss='binary_crossentropy', metrics=['accuracy'])

# Train the model
model.fit(X, y, epochs=100, verbose=1)

# Evaluate
loss, accuracy = model.evaluate(X, y)
print(f"\nAccuracy: {accuracy * 100:.2f}%")

# Predict
print("\nPredictions:")
print(model.predict(X))
# Out:
# Epoch 1/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 501ms/step - accuracy: 0.5000 - loss: 0.8340
# Epoch 2/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.5000 - loss: 0.8146
# Epoch 3/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.5000 - loss: 0.7966
# Epoch 4/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.5000 - loss: 0.7799
# Epoch 5/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.5000 - loss: 0.7644
# Epoch 6/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - accuracy: 0.5000 - loss: 0.7500
# Epoch 7/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.5000 - loss: 0.7366
# Epoch 8/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.5000 - loss: 0.7241
# Epoch 9/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.5000 - loss: 0.7125
# Epoch 10/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.5000 - loss: 0.7016
# Epoch 11/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.5000 - loss: 0.6914
# Epoch 12/100
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt
from keras.models import Sequential
from keras.layers import Dense
from keras.optimizers import SGD

# Input data (AND gate)
X = np.random.randint(0,10,(300000,121))

# Output labels
y = np.random.randint(0, 2, size=(300000,))


# Build the model
model = Sequential()
model.add(Dense(5, input_dim=121, activation='relu'))   # Hidden layer with 5 nodes
model.add(Dense(1, activation='sigmoid'))             # Output layer for binary classification

# Compile the model
model.compile(optimizer=SGD(learning_rate=0.1),
              loss='binary_crossentropy',
              metrics=['accuracy'])

# Train the model and store the training history
history = model.fit(X, y, epochs=100, verbose=0)

# Evaluate the model
loss, accuracy = model.evaluate(X, y, verbose=0)
print(f"\nFinal Accuracy: {accuracy * 100:.2f}%")

# Predict
print("\nPredictions:")
print(model.predict(X))

# Plot loss and accuracy graphs
plt.figure(figsize=(12, 5))

# Plot Loss
plt.subplot(1, 2, 1)
plt.plot(history.history['loss'], color='red', label='Loss')
plt.title('Model Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()

# Plot Accuracy
plt.subplot(1, 2, 2)
plt.plot(history.history['accuracy'], color='blue', label='Accuracy')
plt.title('Model Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()

plt.tight_layout()
plt.show()
# Out:
# Final Accuracy: 49.95%
#
# Predictions:
# 9375/9375 ━━━━━━━━━━━━━━━━━━━━ 9s 930us/step
# [[0.49726456]
#  [0.49726456]
#  [0.49726456]
#  ...
#  [0.49726456]
#  [0.49726456]
#  [0.49726456]]

# %%
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from keras import backend as K

# Define 20 activation functions and their formulas
activation_functions = {
    "linear": lambda x: x,
    "sigmoid": tf.keras.activations.sigmoid,
    "tanh": tf.keras.activations.tanh,
    "relu": tf.keras.activations.relu,
    "softplus": tf.keras.activations.softplus,
    "softsign": tf.keras.activations.softsign,
    "selu": tf.keras.activations.selu,
    "elu": tf.keras.activations.elu,
    "exponential": tf.keras.activations.exponential,
    "hard_sigmoid": tf.keras.activations.hard_sigmoid,
    "swish": lambda x: x * tf.keras.activations.sigmoid(x),
    "mish": lambda x: x * tf.math.tanh(tf.math.softplus(x)),
    "leaky_relu": lambda x: tf.nn.leaky_relu(x, alpha=0.2),
    "prelu": lambda x: tf.maximum(0.1 * x, x),
    "gelu": tf.keras.activations.gelu,
    "bent_identity": lambda x: ((np.sqrt(x ** 2 + 1) - 1) / 2) + x,
    "arctangent": lambda x: tf.math.atan(x),
    "sinc": lambda x: tf.where(x == 0, tf.ones_like(x), tf.math.sin(x) / x),
    "gaussian": lambda x: tf.exp(-tf.square(x)),
    "sign": lambda x: tf.sign(x),
}

# Input range for plotting
x_vals = np.linspace(-10, 10, 500)
x_tensor = tf.convert_to_tensor(x_vals, dtype=tf.float32)

# Plotting
plt.figure(figsize=(20, 20))
for i, (name, func) in enumerate(activation_functions.items()):
    plt.subplot(5, 4, i+1)
    y_vals = func(x_tensor)
    plt.plot(x_vals, y_vals.numpy())
    plt.title(name)
    plt.grid(True)

plt.tight_layout()
plt.suptitle("Activation Functions", fontsize=20, y=1.02)
plt.show()
